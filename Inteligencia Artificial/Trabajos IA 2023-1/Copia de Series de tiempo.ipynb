# %%
# !pip install -U scikit-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.22.4)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.1.0)

# %%
import sklearn
import requests
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Objeto Series con el conjunto de datos.
url = 'https://drive.google.com/uc?export=download&id=16xadwwud_zjDg0tTcMzxDNZbeXK9ez-x' 
agua = pd.read_csv(url,index_col=0)
agua.head()
# Out:
#                                                     initial-scale=1"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.OzCvD8rASHM.L.X.O/am=BjjHYQMAFH8BAhBAoEABAAAAAAAAABAIw1KC/d=1/ed=1/rs=AOaEmlHx9jBSUfQwfN7SOWfSt5N963ip-w/m=identifierview  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                 _b
# (function(){var b=function(e                                                                        p
# '(function(){var $g=function(L                                                                      e
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                      _b  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...  _tp
# (function(){var b=function(e                          L
# '(function(){var $g=function(L                        p
#  Copyright The Closure Library Authors.             NaN
#  SPDX-License-Identifier: Apache-2.0                NaN
#
#                                                                                                   _tp  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...  _r */</style><style nonce="ddEXTeJMFc76KbEjUBi...
# (function(){var b=function(e                                                                        Z
# '(function(){var $g=function(L                                                                      U
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    _r" nonce="ddEXTeJMFc76KbEjUBiqeQ">c-wiz{contain:style}c-wiz>c-data{display:none}c-wiz.rETSD{contain:none}c-wiz.Ubi8Z{contain:layout style}@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...  eyJ2ZXJzaW9uIjogMywic291cmNlcyI6WyIiXSwic291cm...
# (function(){var b=function(e                                                                        U
# '(function(){var $g=function(L                                                                      f
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    -50%) scale(0.2);-webkit-transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                               NaN
# (function(){var b=function(e                                                                       D
# '(function(){var $g=function(L                                                                     D
#  Copyright The Closure Library Authors.                                                          NaN
#  SPDX-License-Identifier: Apache-2.0                                                             NaN
#
#                                                    -50%) scale(0.2);-ms-transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                           NaN
# (function(){var b=function(e                                                                   w
# '(function(){var $g=function(L                                                                 Z
#  Copyright The Closure Library Authors.                                                      NaN
#  SPDX-License-Identifier: Apache-2.0                                                         NaN
#
#                                                          -50%) scale(0.2);-o-transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                        f){return(Z&((Z+2^26)>=Z&&(Z-7^25)<Z&&(L(funct...
# '(function(){var $g=function(L                                                                      T
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                             -50%) scale(0.2);transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                                                w=[function(){return p}])
# '(function(){var $g=function(L                      O){if(((((e<<(e-9>>4||(O=Math.floor(this.M3+(t...
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    -50%) scale(0.2)}to{-webkit-transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                                                 91))==Z&&(f=function(){}
# '(function(){var $g=function(L                      1)&16)<L&&11<=(e>>2&15)&&(T=function(a){return...
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    -50%) scale(2.2);-webkit-transform:translate(-50%  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                               NaN
# (function(){var b=function(e                                                                D=void 0
# '(function(){var $g=function(L                                                            T.listener
#  Copyright The Closure Library Authors.                                                          NaN
#  SPDX-License-Identifier: Apache-2.0                                                             NaN
#
#                                                     ...  \
# <!doctype html><html lang="en-US" dir="ltr"><he...  ...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...  ...
# (function(){var b=function(e                        ...
# '(function(){var $g=function(L                      ...
#  Copyright The Closure Library Authors.             ...
#  SPDX-License-Identifier: Apache-2.0                ...
#
#                                                    37)}.Fu5aXd .azsAwf{margin-left:16px}.Fu5aXd.Jj6Lae .nWPx2e .YhhY8  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                                                                      NaN
# '(function(){var $g=function(L                                                                    NaN
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    .Fu5aXd.Jj6Lae .nWPx2e .CCQ94b  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                            NaN
# (function(){var b=function(e                                                  NaN
# '(function(){var $g=function(L                                                NaN
#  Copyright The Closure Library Authors.                                       NaN
#  SPDX-License-Identifier: Apache-2.0                                          NaN
#
#                                                    .Fu5aXd.Jj6Lae .nWPx2e .tNASEf{border-color:rgb(217  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                                                                      NaN
# '(function(){var $g=function(L                                                                    NaN
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    48.1  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...  NaN
# (function(){var b=function(e                        NaN
# '(function(){var $g=function(L                      NaN
#  Copyright The Closure Library Authors.             NaN
#  SPDX-License-Identifier: Apache-2.0                NaN
#
#                                                    37)}.Fu5aXd.Jj6Lae .nWPx2e .CCQ94b{color:rgb(217  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                              NaN
# (function(){var b=function(e                                                                    NaN
# '(function(){var $g=function(L                                                                  NaN
#  Copyright The Closure Library Authors.                                                         NaN
#  SPDX-License-Identifier: Apache-2.0                                                            NaN
#
#                                                    48.2  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...  NaN
# (function(){var b=function(e                        NaN
# '(function(){var $g=function(L                      NaN
#  Copyright The Closure Library Authors.             NaN
#  SPDX-License-Identifier: Apache-2.0                NaN
#
#                                                    37)}.d2laFc .wLBAL[data-email$="@glimitedaccount.com"]{display:none}.lPxAeb .yAlK0b[data-email$="@glimitedaccount.com"]{display:none}.ZWssT{margin-top:26px}.vopC4e{background:transparent;border:none;-webkit-box-sizing:border-box;box-sizing:border-box;color:#202124;cursor:pointer;margin-bottom:-15px;margin-top:-15px;outline:inherit;padding-bottom:15px;padding-top:15px;position:relative;z-index:1}.vopC4e:focus::after{background-color:rgba(26  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                                                                      NaN
# '(function(){var $g=function(L                                                                    NaN
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
#                                                    115.42 232.4  \
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...    NaN   NaN
# (function(){var b=function(e                          NaN   NaN
# '(function(){var $g=function(L                        NaN   NaN
#  Copyright The Closure Library Authors.               NaN   NaN
#  SPDX-License-Identifier: Apache-2.0                  NaN   NaN
#
#                                                    0.15);-webkit-border-radius:2px;-moz-border-radius:2px;border-radius:2px;bottom:0;content:"";left:0;position:absolute;right:0;top:0;z-index:-1}.JVMrYb{display:block}.hJIRO{display:none}.sQecwc{display:hidden}sentinel{}
# <!doctype html><html lang="en-US" dir="ltr"><he...
# /*# sourceURL=/_/mss/boq-identity/_/ss/k=boq-id...                                                NaN
# (function(){var b=function(e                                                                      NaN
# '(function(){var $g=function(L                                                                    NaN
#  Copyright The Closure Library Authors.                                                           NaN
#  SPDX-License-Identifier: Apache-2.0                                                              NaN
#
# [5 rows x 5437 columns]

# %%
agua.describe()
# Out:
#        1)}.VfPpkd-ksKsZd-XxIAqe::after{z-index:0;z-index:var(--mdc-ripple-z-index  \
# count                                           2.000000
# mean                                           29.000000
# std                                            24.041631
# min                                            12.000000
# 25%                                            20.500000
# 50%                                            29.000000
# 75%                                            37.500000
# max                                            46.000000
#
#        background-color 15ms linear;-o-transition:opacity 15ms linear.1  \
# count                                                1.0
# mean                                                 0.0
# std                                                  NaN
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        background-color 15ms linear;transition:opacity 15ms linear.1  \
# count                                                1.0
# mean                                                55.0
# std                                                  NaN
# min                                                 55.0
# 25%                                                 55.0
# 50%                                                 55.0
# 75%                                                 55.0
# max                                                 55.0
#
#        0)}.VfPpkd-Bz112c-LgbsSe.VfPpkd-ksKsZd-mWPk3d .VfPpkd-Bz112c-Jh9lGc::before{-webkit-transform:scale(var(--mdc-ripple-fg-scale  \
# count                                                1.0
# mean                                                27.0
# std                                                  NaN
# min                                                 27.0
# 25%                                                 27.0
# 50%                                                 27.0
# 75%                                                 27.0
# max                                                 27.0
#
#        1));-moz-transform:scale(var(--mdc-ripple-fg-scale  \
# count                                                1.0
# mean                                                32.0
# std                                                  NaN
# min                                                 32.0
# 25%                                                 32.0
# 50%                                                 32.0
# 75%                                                 32.0
# max                                                 32.0
#
#        1));-ms-transform:scale(var(--mdc-ripple-fg-scale.1  \
# count                                                1.0
# mean                                                 1.0
# std                                                  NaN
# min                                                  1.0
# 25%                                                  1.0
# 50%                                                  1.0
# 75%                                                  1.0
# max                                                  1.0
#
#        1));-o-transform:scale(var(--mdc-ripple-fg-scale.1  \
# count                                                1.0
# mean                                                64.0
# std                                                  NaN
# min                                                 64.0
# 25%                                                 64.0
# 50%                                                 64.0
# 75%                                                 64.0
# max                                                 64.0
#
#        -50%);-o-transform:translate(-50%.3  1).3  \
# count                                  1.0   1.0
# mean                                  56.0   0.0
# std                                    NaN   NaN
# min                                   56.0   0.0
# 25%                                   56.0   0.0
# 50%                                   56.0   0.0
# 75%                                   56.0   0.0
# max                                   56.0   0.0
#
#        -moz-box-shadow .28s cubic-bezier(.4.1  ...  \
# count                                     1.0  ...
# mean                                      8.0  ...
# std                                       NaN  ...
# min                                       8.0  ...
# 25%                                       8.0  ...
# 50%                                       8.0  ...
# 75%                                       8.0  ...
# max                                       8.0  ...
#
#        37)}.Fu5aXd .azsAwf{margin-left:16px}.Fu5aXd.Jj6Lae .nWPx2e .YhhY8  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        .Fu5aXd.Jj6Lae .nWPx2e .CCQ94b  \
# count                             0.0
# mean                              NaN
# std                               NaN
# min                               NaN
# 25%                               NaN
# 50%                               NaN
# 75%                               NaN
# max                               NaN
#
#        .Fu5aXd.Jj6Lae .nWPx2e .tNASEf{border-color:rgb(217  48.1  \
# count                                                0.0     0.0
# mean                                                 NaN     NaN
# std                                                  NaN     NaN
# min                                                  NaN     NaN
# 25%                                                  NaN     NaN
# 50%                                                  NaN     NaN
# 75%                                                  NaN     NaN
# max                                                  NaN     NaN
#
#        37)}.Fu5aXd.Jj6Lae .nWPx2e .CCQ94b{color:rgb(217  48.2  \
# count                                               0.0   0.0
# mean                                                NaN   NaN
# std                                                 NaN   NaN
# min                                                 NaN   NaN
# 25%                                                 NaN   NaN
# 50%                                                 NaN   NaN
# 75%                                                 NaN   NaN
# max                                                 NaN   NaN
#
#        37)}.d2laFc .wLBAL[data-email$="@glimitedaccount.com"]{display:none}.lPxAeb .yAlK0b[data-email$="@glimitedaccount.com"]{display:none}.ZWssT{margin-top:26px}.vopC4e{background:transparent;border:none;-webkit-box-sizing:border-box;box-sizing:border-box;color:#202124;cursor:pointer;margin-bottom:-15px;margin-top:-15px;outline:inherit;padding-bottom:15px;padding-top:15px;position:relative;z-index:1}.vopC4e:focus::after{background-color:rgba(26  \
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        115.42  232.4  \
# count     0.0    0.0
# mean      NaN    NaN
# std       NaN    NaN
# min       NaN    NaN
# 25%       NaN    NaN
# 50%       NaN    NaN
# 75%       NaN    NaN
# max       NaN    NaN
#
#        0.15);-webkit-border-radius:2px;-moz-border-radius:2px;border-radius:2px;bottom:0;content:"";left:0;position:absolute;right:0;top:0;z-index:-1}.JVMrYb{display:block}.hJIRO{display:none}.sQecwc{display:hidden}sentinel{}
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
# [8 rows x 2639 columns]

# %%
agua_short = agua.sample(n=5)

agua_short.plot(rot=180, figsize=(12, 5), fontsize=13.5)
# Out:
# <Axes: >

# %%
data_train = mintemp.loc[:'1986-12-31']
data_test  = mintemp.loc['1987-01-01':]
data_train.index[-1], data_test.index[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index._unpack_bool_indexer()
#
# KeyError: '1986-12-31'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-b23140f01dd6> in <cell line: 1>()
# ----> 1 data_train = mintemp.loc[:'1986-12-31']
#       2 data_test  = mintemp.loc['1987-01-01':]
#       3 data_train.index[-1], data_test.index[0]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1288         if isinstance(key, slice):
#    1289             self._validate_key(key, axis)
# -> 1290             return self._get_slice_axis(key, axis=axis)
#    1291         elif com.is_bool_indexer(key):
#    1292             return self._getbool_axis(key, axis=axis)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1322
#    1323         labels = obj._get_axis(axis)
# -> 1324         indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1325
#    1326         if isinstance(indexer, slice):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in slice_indexer(self, start, end, step, kind)
#    6557         self._deprecated_arg(kind, "kind", "slice_indexer")
#    6558
# -> 6559         start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6560
#    6561         # return a slice
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in slice_locs(self, start, end, step, kind)
#    6771         end_slice = None
#    6772         if end is not None:
# -> 6773             end_slice = self.get_slice_bound(end, "right")
#    6774         if end_slice is None:
#    6775             end_slice = len(self)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    6684             except ValueError:
#    6685                 # raise the original KeyError
# -> 6686                 raise err
#    6687
#    6688         if isinstance(slc, np.ndarray):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_slice_bound(self, label, side, kind)
#    6678         # we need to look up the label
#    6679         try:
# -> 6680             slc = self.get_loc(label)
#    6681         except KeyError as err:
#    6682             try:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '1986-12-31'

# %%
def sliding_time(ts, window_size=1):

  n = ts.shape[0] - window_size  
  X = np.empty((n, window_size))
  y = np.empty(n)

  for i in range(window_size, ts.shape[0]):   
    y[i - window_size] = ts[i]
    X[i- window_size, 0:window_size] = np.array(ts[i - window_size:i].transpose())
    
  return X, y

# %%
X_train, y_train = sliding_time(data_train.values, window_size=20)

# %%
print(f"Número de ejemplos de entrenamiento: {X_train.shape[0]} (Ventana de tamaño {X_train.shape[1]})")
print(f"Número de valores a predecir: {y_train.shape[0]}")

# %%
X_test, y_test = sliding_time(data_test.values, window_size=20)

# %%
print(f"Número de ejemplos de prueba: {X_test.shape[0]} (Ventana de tamaño {X_test.shape[1]})")
print(f"Número de valores a predecir: {y_test.shape[0]}")

# %%
pd.DataFrame(X_train)

# %%
from sklearn.neural_network import MLPRegressor 

model = MLPRegressor(solver = 'lbfgs',
                   activation = 'relu',
                   hidden_layer_sizes=(120, 60, 30),
                   max_iter=50,                   
                   n_iter_no_change=50, 
                   validation_fraction=0.2,               
                   random_state=1234)

# %%
model.fit(X_train, y_train)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error 

y_pred = model.predict(X_test)

print(f"Test Mean Squared Error: \t{mean_squared_error(y_test, y_pred):.4f}")
print(f"Test Mean Absolute Error: \t{mean_absolute_error(y_test, y_pred):.4f}")
print(f"Test Mean squared log error: \t{mean_squared_log_error(y_test, y_pred):.4f}")

# %%
x = data_test.index[20:]

plt.figure(figsize=(10,3), dpi = 105)
plt.plot(x, y_test, ls = "--", label="Valor verdadero (pruebas)")
plt.plot(x, y_pred, ls = '-', label="Valor predicho (pruebas)")
plt.title("Predicción vs valores verdaderos (pruebas)")
plt.legend();
