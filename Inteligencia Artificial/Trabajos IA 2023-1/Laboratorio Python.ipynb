# %% [markdown]
# Como crear una lista de caracteres

# %%
fruits = ['orange', 'apple', 'pear', 'banana', 'kiwi', 'apple', 'banana']
print(fruits[3])
# Out:
# banana

# %%
num=fruits.count('apple')
print(num)
# Out:
# 2

# %%
fruits.count('tangerine')
# Out:
# 0

# %%
fruits.index('banana')
# Out:
# 3

# %%
fruits.index('banana', 4)
# Out:
# 6

# %%
fruits.reverse()
fruits
# Out:
# ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange']

# %%
fruits.append('grape')
fruits
# Out:
# ['banana', 'apple', 'kiwi', 'banana', 'pear', 'apple', 'orange', 'grape']

# %%
fruits.sort()
fruits
# Out:
# ['apple', 'apple', 'banana', 'banana', 'grape', 'kiwi', 'orange', 'pear']

# %%
fruits.pop()
# Out:
# 'pear'

# %%
for pos,fruit in enumerate(fruits):
  print(pos,fruit)
# Out:
# 0 apple
# 1 apple
# 2 banana
# 3 banana
# 4 grape
# 5 kiwi
# 6 orange

# %% [markdown]
# 5.1.1 Usando lista como pila

# %%
stack = [3, 4, 5]

# %%
stack.append(6)

# %%
stack.append(7)
stack
# Out:
# [3, 4, 5, 6, 7]

# %%
stack.pop()
stack
# Out:
# [3, 4, 5, 6]

# %%
stack.pop()
stack
# Out:
# [3, 4, 5]

# %%
stack.pop()
stack
# Out:
# [3, 4]

# %% [markdown]
# 5.1.2 Usando listas como colas

# %%
from collections import deque

# %%
queue = deque(["Eric", "John", "Michael"])

# %%
queue.append("Terry")

# %%
queue.append("Graham")

# %%
queue.popleft()
# Out:
# 'Eric'

# %%
queue.popleft()
# Out:
# 'John'

# %%
queue
# Out:
# deque(['Michael', 'Terry', 'Graham'])

# %% [markdown]
# 5.1.3 Comprension de listas

# %%
squares = []
for x in range(10):
    squares.append(x**2)

print(squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
squares2 = list(map(lambda x: x**2, range(0,100,2)))
print(squares2)
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324, 400, 484, 576, 676, 784, 900, 1024, 1156, 1296, 1444, 1600, 1764, 1936, 2116, 2304, 2500, 2704, 2916, 3136, 3364, 3600, 3844, 4096, 4356, 4624, 4900, 5184, 5476, 5776, 6084, 6400, 6724, 7056, 7396, 7744, 8100, 8464, 8836, 9216, 9604]

# %%
squares3 = [x**3 for x in range(1,49)]
print(squares3)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000, 1331, 1728, 2197, 2744, 3375, 4096, 4913, 5832, 6859, 8000, 9261, 10648, 12167, 13824, 15625, 17576, 19683, 21952, 24389, 27000, 29791, 32768, 35937, 39304, 42875, 46656, 50653, 54872, 59319, 64000, 68921, 74088, 79507, 85184, 91125, 97336, 103823, 110592]

# %%
lista1=[1,2,3]
lista2=[3,1,4]
lista3=[(x, y) for x in lista1 for y in lista2 if x != y]
print(lista3)
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]

# %%
listaBebidas=['agua','leche','agua de coco','leche almendra']
listaBatidos=[(x, y) for x in fruits for y in listaBebidas if x != y]
print(listaBatidos)
# Out:
# [('apple', 'agua'), ('apple', 'leche'), ('apple', 'agua de coco'), ('apple', 'leche almendra'), ('apple', 'agua'), ('apple', 'leche'), ('apple', 'agua de coco'), ('apple', 'leche almendra'), ('banana', 'agua'), ('banana', 'leche'), ('banana', 'agua de coco'), ('banana', 'leche almendra'), ('banana', 'agua'), ('banana', 'leche'), ('banana', 'agua de coco'), ('banana', 'leche almendra'), ('grape', 'agua'), ('grape', 'leche'), ('grape', 'agua de coco'), ('grape', 'leche almendra'), ('kiwi', 'agua'), ('kiwi', 'leche'), ('kiwi', 'agua de coco'), ('kiwi', 'leche almendra'), ('orange', 'agua'), ('orange', 'leche'), ('orange', 'agua de coco'), ('orange', 'leche almendra')]

# %%
fruits2=fruits.copy()
fruits2.append('strawberry')
print(fruits)
# Out:
# ['apple', 'apple', 'banana', 'banana', 'grape', 'kiwi', 'orange']

# %%
combs = []
for x in [1,2,3]:
    for y in [3,1,4]:
        if x != y:
            combs.append((x, y))

print(combs)
# Out:
# [(1, 3), (1, 4), (2, 3), (2, 1), (2, 4), (3, 1), (3, 4)]

# %%
from math import pi
[str(round(pi, i)) for i in range(1, 6)]
# Out:
# ['3.1', '3.14', '3.142', '3.1416', '3.14159']

# %%
matrix = [
    [1, 2, 3, 4],
    [5, 6, 7, 8,12],
    [9, 6, 11, 7],
]
for row in matrix:
  for col in row:
    print(col,end= " ")
# Out:
# 1 2 3 4 5 6 7 8 12 9 6 11 7

# %% [markdown]
# 5.2. La instrucción del

# %%
a = [-1, 1, 66.25, 333, 333, 1234.5]
del a[0]
a
# Out:
# [1, 66.25, 333, 333, 1234.5]

# %%
del a[2:4]
a
# Out:
# [1, 66.25, 1234.5]

# %%
del a[:]
a
# Out:
# []

# %% [markdown]
# 5.3 Tuplas y secuencias

# %%
t = 12345, 54321, 'hello!'
t[0]
# Out:
# 12345

# %%
t
# Out:
# (12345, 54321, 'hello!')

# %%
u = t, (1, 2, 3, 4, 5)
u
# Out:
# ((12345, 54321, 'hello!'), (1, 2, 3, 4, 5))

# %%
empty = ()
singleton = 'hello',  
len(empty)
# Out:
# 0

# %%
len(singleton)
# Out:
# 1

# %% [markdown]
# 5.4 CONJUNTOS

# %%
basket = {'apple', 'orange', 'apple', 'pear', 'orange', 'banana'}

# %%
print(basket)
# Out:
# {'apple', 'pear', 'orange', 'banana'}

# %%
'orange' in basket
# Out:
# True

# %%
'crabgrass' in basket
# Out:
# False

# %%
a = set('abracadabra')
b = set('alacazam')

# %%
a
# Out:
# {'a', 'b', 'c', 'd', 'r'}

# %%
a - b
# Out:
# {'b', 'd', 'r'}

# %%
a | b
# Out:
# {'a', 'b', 'c', 'd', 'l', 'm', 'r', 'z'}

# %%
a & b
# Out:
# {'a', 'c'}

# %%
a ^ b
# Out:
# {'b', 'd', 'l', 'm', 'r', 'z'}

# %% [markdown]
# 5.5 DICCIONARIOS

# %%
tel = {'jack': 4098, 'sape': 4139}
tel['guido'] = 4127
tel
# Out:
# {'jack': 4098, 'sape': 4139, 'guido': 4127}

# %%
tel['jack']
# Out:
# 4098

# %%
del tel['sape']

# %%
tel['irv'] = 4127

# %%
print(tel)
# Out:
# {'jack': 4098, 'guido': 4127, 'irv': 4127}

# %%
sorted(tel)
# Out:
# ['guido', 'irv', 'jack']

# %%
'guido' in tel
# Out:
# True

# %%
'jack' not in tel
# Out:
# False

# %% [markdown]
# 5.6. Técnicas de iteración

# %%
knights = {'gallahad': 'the pure', 'robin': 'the brave'}

# %%
for k, v in knights.items():
    print(k, v)
# Out:
# gallahad the pure
# robin the brave

# %%
for i, v in enumerate(['tic', 'tac', 'toe']):
    print(i, v)
# Out:
# 0 tic
# 1 tac
# 2 toe

# %%
questions = ['name', 'quest', 'favorite color']
answers = ['lancelot', 'the holy grail', 'blue']

# %%
for q, a in zip(questions, answers):
    print('What is your {0}?  It is {1}.'.format(q, a))
# Out:
# What is your name?  It is lancelot.
# What is your quest?  It is the holy grail.
# What is your favorite color?  It is blue.

# %%
for i in reversed(range(1, 10, 2)):
    print(i)
# Out:
# 9
# 7
# 5
# 3
# 1

# %%
basket = ['apple', 'orange', 'apple', 'pear', 'orange', 'banana']
for i in sorted(basket):
    print(i)
# Out:
# apple
# apple
# banana
# orange
# orange
# pear

# %%
for f in sorted(set(basket)):
    print(f)
# Out:
# apple
# banana
# orange
# pear

# %%
import math
raw_data = [56.2, float('NaN'), 51.7, 55.3, 52.5, float('NaN'), 47.8]
filtered_data = []
for value in raw_data:
    if not math.isnan(value):
        filtered_data.append(value)

filtered_data
# Out:
# [56.2, 51.7, 55.3, 52.5, 47.8]

# %% [markdown]
# 5.7. Más acerca de condiciones

# %%
string1, string2, string3 = '', 'Trondheim', 'Hammer Dance'

# %%
non_null = string1 or string2 or string3

# %%
non_null
# Out:
# 'Trondheim'

# %% [markdown]
# 5.8. Comparando secuencias y otros tipos

# %%
(1, 2, 3)              < (1, 2, 4)
[1, 2, 3]              < [1, 2, 4]
'ABC' < 'C' < 'Pascal' < 'Python'
(1, 2, 3, 4)           < (1, 2, 4)
(1, 2)                 < (1, 2, -1)
(1, 2, 3)             == (1.0, 2.0, 3.0)
(1, 2, ('aa', 'ab'))   < (1, 2, ('abc', 'a'), 4)
# Out:
# True

# %% [markdown]
# 9.CLASES
# 9.1 Unas palabras sobre nombres y objetos

# %% [markdown]
# 9.2. Ámbitos y espacios de nombres en Python
# 9.2.1. Ejemplo de ámbitos y espacios de nombre

# %%
def scope_test():
    def do_local():
        spam = "local spam"

    def do_nonlocal():
        nonlocal spam
        spam = "nonlocal spam"

    def do_global():
        global spam
        spam = "global spam"

    spam = "test spam"
    do_local()
    print("After local assignment:", spam)
    do_nonlocal()
    print("After nonlocal assignment:", spam)
    do_global()
    print("After global assignment:", spam)

scope_test()
print("In global scope:", spam)
# Out:
# After local assignment: test spam
# After nonlocal assignment: nonlocal spam
# After global assignment: nonlocal spam
# In global scope: global spam

# %% [markdown]
# 9.3. Un primer vistazo a las clases
# 9.3.1. Sintaxis de definición de clases

# %%
class MyClass:
    """A simple example class"""
    i = 12345

    def f(self):
        return 'hello world'
x = MyClass()

# %%
class Complex:
    def __init__(self, realpart, imagpart):
        self.r = realpart
        self.i = imagpart

x = Complex(3.0, -4.5)
x.r, x.i
# Out:
# (3.0, -4.5)

# %% [markdown]
# 9.3.3. Objetos instancia

# %%
x.counter = 1
while x.counter < 10:
    x.counter = x.counter * 2
print(x.counter)
del x.counter
# Out:
# 16

# %% [markdown]
# 9.3.4. Objetos método

# %%
class Dog:

    kind = 'canine'         # class variable shared by all instances

    def __init__(self, name):
        self.name = name    # instance variable unique to each instance
d = Dog('Fido')
e = Dog('Buddy')
d.kind
# Out:
# 'canine'

# %%
e.kind
# Out:
# 'canine'

# %%
d.name
# Out:
# 'Fido'

# %%
class Dog:

    tricks = []             # mistaken use of a class variable

    def __init__(self, name):
        self.name = name

    def add_trick(self, trick):
        self.tricks.append(trick)

d = Dog('Fido')
e = Dog('Buddy')
d.add_trick('roll over')
e.add_trick('play dead')

# %%
d.tricks
# Out:
# ['roll over', 'play dead']

# %%
class Dog:

    def __init__(self, name):
        self.name = name
        self.tricks = []    # creates a new empty list for each dog

    def add_trick(self, trick):
        self.tricks.append(trick)

d = Dog('Fido')
e = Dog('Buddy')
d.add_trick('roll over')
e.add_trick('play dead')

# %%
d.tricks
# Out:
# ['roll over']

# %%
e.tricks
# Out:
# ['play dead']

# %% [markdown]
# 9.3.5. Variables de clase y de instancia

# %%
class Dog:

    def __init__(self, name):
        self.name = name
        self.tricks = []    # creates a new empty list for each dog

    def add_trick(self, trick):
        self.tricks.append(trick)

d = Dog('Fido')
e = Dog('Buddy')
d.add_trick('roll over')
e.add_trick('play dead')

# %%
d.tricks
# Out:
# ['roll over']

# %%
e.tricks
# Out:
# ['play dead']

# %% [markdown]
# 9.4. Algunas observaciones

# %%
class Warehouse:
   purpose = 'storage'
   region = 'west'

w1 = Warehouse()
print(w1.purpose, w1.region)
# Out:
# storage west

# %%
w2 = Warehouse()
w2.region = 'east'
print(w2.purpose, w2.region)
# Out:
# storage east

# %%
def f1(self, x, y):
    return min(x, x+y)

class C:
    f = f1

    def g(self):
        return 'hello world'

    h = g

# %%
class Bag:
    def __init__(self):
        self.data = []

    def add(self, x):
        self.data.append(x)

    def addtwice(self, x):
        self.add(x)
        self.add(x)

# %% [markdown]
# 9.5. Herencia
# 9.5.1. Herencia múltiple

# %% [markdown]
# 9.6. Variables privadas

# %%
class Mapping:
    def __init__(self, iterable):
        self.items_list = []
        self.__update(iterable)

    def update(self, iterable):
        for item in iterable:
            self.items_list.append(item)

    __update = update   # private copy of original update() method

# %%
class MappingSubclass(Mapping):

    def update(self, keys, values):
        # provides new signature for update()
        # but does not break __init__()
        for item in zip(keys, values):
            self.items_list.append(item)

# %% [markdown]
# 9.7. Cambalache

# %%
from dataclasses import dataclass

@dataclass
class Employee:
    name: str
    dept: str
    salary: int

# %%
john = Employee('john', 'computer lab', 1000)
john.dept
# Out:
# 'computer lab'

# %%
john.salary
# Out:
# 1000

# %% [markdown]
# 9.8. Iteradores

# %%
for element in [1, 2, 3]:
    print(element)
# Out:
# 1
# 2
# 3

# %%
for element in (1, 2, 3):
    print(element)
# Out:
# 1
# 2
# 3

# %%
for key in {'one':1, 'two':2}:
    print(key)
# Out:
# one
# two

# %%
for char in "123":
    print(char)
# Out:
# 1
# 2
# 3

# %%
s = 'abc'
it = iter(s)

# %%
it

# %%
next(it)
# Out:
# 'a'

# %%
next(it)
# Out:
# 'b'

# %%
next(it)
# Out:
# 'c'

# %%
class Reverse:
    """Iterator for looping over a sequence backwards."""
    def __init__(self, data):
        self.data = data
        self.index = len(data)

    def __iter__(self):
        return self

    def __next__(self):
        if self.index == 0:
            raise StopIteration
        self.index = self.index - 1
        return self.data[self.index]

# %%
rev = Reverse('spam')
iter(rev)

# %%
for char in rev:
    print(char)
# Out:
# m
# a
# p
# s

# %% [markdown]
# 9.9 Generadores

# %%
def reverse(data):
    for index in range(len(data)-1, -1, -1):
        yield data[index]

# %%
for char in reverse('golf'):
    print(char)
# Out:
# f
# l
# o
# g

# %% [markdown]
# 9.10. Expresiones generadoras

# %%
sum(i*i for i in range(10))
# Out:
# 285

# %%
xvec = [10, 20, 30]
yvec = [7, 5, 3]
sum(x*y for x,y in zip(xvec, yvec))
# Out:
# 260
